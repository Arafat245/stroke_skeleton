# %%
import os
import re
import random
import numpy as np
import torch
import time
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from tqdm.notebook import tqdm

from data_utils_load import *
from transformer import Transformer

device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')

def filter_valid_files(file_list):
    valid_files = []
    for file in file_list:
        file = file.strip()
        if re.match(r'^ID\d+_\d+\.csv$', file):
            valid_files.append(file)
    return valid_files

def set_deterministic(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

bsize = 64

# %% [markdown]
# ## Loading Data

# %%
save_dir = 'data'
loaded_dir = 'csv_r'
# preprocess_and_save_data(loaded_dir, save_dir)
all_files = filter_valid_files(os.listdir(loaded_dir))
participant_ids = sorted({re.search(r'ID(\d+)_', f).group(1) for f in all_files}, key=lambda x: int(x))

# %% [markdown]
# ## Gait Unit Creation

# %%
class GaitUnitsDataset(Dataset):
    def __init__(self, x_load_list, y_batch, N_gaits):
        self.unit_samples = []
        self.unit_labels = []
        
        for x_task, y_task in zip(x_load_list, y_batch):
            L = x_task.size(0)
            num_units = L - N_gaits + 1
            units = [x_task[start:start + N_gaits] for start in range(num_units)]
            self.unit_samples.extend(units)
            self.unit_labels.extend([y_task] * num_units)
        print(f"Created {len(self.unit_samples)} gait windows")
    
    def __len__(self):
        return len(self.unit_samples)
    
    def __getitem__(self, idx):
        return self.unit_samples[idx], self.unit_labels[idx]


def create_gait_units_dataloader(x_load_list, y_batch, N_gaits, batch_size=64, shuffle=True):
    dataset = GaitUnitsDataset(x_load_list, y_batch, N_gaits)
    return DataLoader(dataset, batch_size=batch_size, shuffle=shuffle)

# %% [markdown]
# ## Evaluation Function

# %%
def evaluate_model(model, test_loader, n_select_gaits):

    model.eval()
    device = next(model.parameters()).device

    t = []
    p = []

    with torch.no_grad():
        for batch in test_loader:
            if len(batch) == 3:
                x_load_list, y_batch, _ = batch
            else:
                x_load_list, y_batch = batch

            for i, x_load_sample in enumerate(x_load_list):
                x_task = x_load_sample[:6]
                num_units = len(x_task) - n_select_gaits + 1

                unit_preds = []
                    
                for start_idx in range(num_units):
                    unit = x_task[start_idx:start_idx + n_select_gaits]
                    unit_tensor = unit.unsqueeze(0).to(device)
                    y_target = y_batch[i:i+1].to(device)
                        
                    y_pred = model(unit_tensor)
                    unit_preds.append(y_pred.item())

                participant_target = y_target.item()
                participant_pred = float(np.median(np.array(unit_preds)))

                t.append(participant_target)
                p.append(participant_pred)
    
    return t, p

# %% [markdown]
# ## Model Training Function

# %%
def train_model(model, train_loader, experiment_seed=42, num_epochs=1000, N_gaits=2, val_loader=None, patience=50):
    set_deterministic(experiment_seed)
    random.seed(experiment_seed)
    np.random.seed(experiment_seed)

    all_x = []
    all_y = []
    
    for batch in train_loader:
        if len(batch) == 3:
            x_load_list, y_batch, _ = batch
        else:
            x_load_list, y_batch = batch
        all_x.extend(x_load_list)
        all_y.extend(y_batch)
    
    optimized_train_loader = create_gait_units_dataloader(all_x, all_y, N_gaits=N_gaits, 
                                                          batch_size=bsize, shuffle=True)
    
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-4)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=num_epochs)

    best_val_mae = float('inf')
    best_state = None
    epochs_no_improve = 0

    print("Starting training...")
    for epoch in range(num_epochs):
        model.train()
        total_loss = 0
        
        for x_batch, y_batch in optimized_train_loader:
            x_batch = x_batch.to(device) 
            y_batch = y_batch.to(device)  
            
            y_pred = model(x_batch).view(-1)
            loss = F.l1_loss(y_pred, y_batch)
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        
        scheduler.step()

        if val_loader is not None:
            val_t, val_p = evaluate_model(model, val_loader, n_select_gaits=N_gaits)
            val_mae = np.mean(np.abs(np.array(val_t) - np.array(val_p)))
            if val_mae < best_val_mae:
                best_val_mae = val_mae
                best_state = {k: v.cpu().clone() for k, v in model.state_dict().items()}
                epochs_no_improve = 0
            else:
                epochs_no_improve += 1
            if epochs_no_improve >= patience:
                print(f"Early stopping at epoch {epoch + 1} (no improvement for {patience} epochs)")
                if best_state is not None:
                    model.load_state_dict(best_state)
                break
        
        if (epoch + 1) % 100 == 0:
            avg_loss = total_loss / len(optimized_train_loader)
            msg = f"[Epoch {epoch + 1}/{num_epochs}] Train MAE: {avg_loss:.4f}"
            if val_loader is not None:
                msg += f" | Val MAE: {val_mae:.4f}"
            print(msg)

    if val_loader is not None and best_state is not None:
        model.load_state_dict(best_state)
    return model

# %% [markdown]
# ## Transformer Training

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from val_test import val_test
import pandas as pd
from print_results import print_results

n_folds = 30
models = {'Transformer': []}
name = list(models.keys())[0]
all_results_validation = {name: {'targets': [], 'preds': []}}
all_results_test = {name: {'targets': [], 'preds': [], 'subjects': []}}


for k in tqdm(range(n_folds)):
    
    model = Transformer(N_gaits=2).to(device)

    validation_pids, test_pids = val_test(participant_ids, k)
    print(f"Fold {k+1} | Validation Subs: {validation_pids} | Test Subs: {test_pids}")

    train_loader, val_loader, test_loader = cv_data_create(validation_pids, test_pids, save_dir, batch_size=bsize)
    trained_model = train_model(model, train_loader, experiment_seed=k, val_loader=val_loader, patience=150)

    val_t, val_p = evaluate_model(trained_model, val_loader, n_select_gaits=2)
    test_t, test_p = evaluate_model(trained_model, test_loader, n_select_gaits=2)

    all_results_validation[name]['targets'].extend(val_t)
    all_results_validation[name]['preds'].extend(val_p)
    all_results_test[name]['targets'].extend(test_t)
    all_results_test[name]['preds'].extend(test_p)
    all_results_test[name]['subjects'].extend(test_pids)

    mae_val = mean_absolute_error(val_t, val_p)
    rmse_val = np.sqrt(mean_squared_error(val_t, val_p))
    r2_val = r2_score(val_t, val_p)
    print(f"Fold {k + 1:02d} | {name} | Validation: MAE={mae_val:.3f}, RMSE={rmse_val:.3f}, R2={r2_val:.3f}\n")

test_results_df = print_results(all_results_validation, all_results_test, models)
test_results_df
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Fold 1 | Validation Subs: ['1', '2', '3', '4', '5'] | Test Subs: ['6', '7', '8', '10', '11']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.6485 | Val MAE: 5.5663
# [Epoch 200/1000] Train MAE: 0.5007 | Val MAE: 4.1234
# Early stopping at epoch 287 (no improvement for 150 epochs)
# Fold 01 | Transformer | Validation: MAE=3.688, RMSE=4.793, R2=0.043
#
# Fold 2 | Validation Subs: ['13', '14', '15', '17', '18'] | Test Subs: ['19', '20', '21', '22', '23']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.6544 | Val MAE: 6.0040
# Early stopping at epoch 151 (no improvement for 150 epochs)
# Fold 02 | Transformer | Validation: MAE=5.004, RMSE=6.086, R2=-2.087
#
# Fold 3 | Validation Subs: ['24', '25', '26', '27', '28'] | Test Subs: ['29', '30', '31', '32', '33']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.5929 | Val MAE: 7.1556
# Early stopping at epoch 172 (no improvement for 150 epochs)
# Fold 03 | Transformer | Validation: MAE=4.047, RMSE=4.546, R2=-0.005
#
# Fold 4 | Validation Subs: ['34', '35', '36', '37', '38'] | Test Subs: ['40', '41', '42', '43', '45']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.5943 | Val MAE: 4.4564
# Early stopping at epoch 167 (no improvement for 150 epochs)
# Fold 04 | Transformer | Validation: MAE=2.242, RMSE=3.769, R2=0.715
#
# Fold 5 | Validation Subs: ['46', '47', '48', '49', '51'] | Test Subs: ['52', '53', '54', '55', '56']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.7316 | Val MAE: 5.4086
# Early stopping at epoch 171 (no improvement for 150 epochs)
# Fold 05 | Transformer | Validation: MAE=1.195, RMSE=1.499, R2=0.926
#
# Fold 6 | Validation Subs: ['57', '58', '59', '60', '61'] | Test Subs: ['62', '63', '64', '65', '66']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.6849 | Val MAE: 2.5678
# Early stopping at epoch 181 (no improvement for 150 epochs)
# Fold 06 | Transformer | Validation: MAE=0.973, RMSE=0.979, R2=0.000
#
# Fold 7 | Validation Subs: ['67', '68', '69', '70', '71'] | Test Subs: ['72', '73', '74', '75', '76']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.7698 | Val MAE: 1.9007
# Early stopping at epoch 155 (no improvement for 150 epochs)
# Fold 07 | Transformer | Validation: MAE=0.646, RMSE=0.729, R2=0.000
#
# Fold 8 | Validation Subs: ['77', '78', '79', '80', '81'] | Test Subs: ['82', '83', '84', '85', '86']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.6988 | Val MAE: 2.6958
# Early stopping at epoch 155 (no improvement for 150 epochs)
# Fold 08 | Transformer | Validation: MAE=1.146, RMSE=1.231, R2=0.000
#
# Fold 9 | Validation Subs: ['87', '88', '89', '90', '92'] | Test Subs: ['94', '95', '97', '98', '99']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.6765 | Val MAE: 2.5599
# Early stopping at epoch 173 (no improvement for 150 epochs)
# Fold 09 | Transformer | Validation: MAE=1.073, RMSE=1.105, R2=0.000
#
# Fold 10 | Validation Subs: ['100', '102', '103', '105', '106'] | Test Subs: ['107', '109', '111', '112', '113']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.7158 | Val MAE: 1.6593
# Early stopping at epoch 165 (no improvement for 150 epochs)
# Fold 10 | Transformer | Validation: MAE=0.753, RMSE=0.832, R2=0.000
#
# Fold 11 | Validation Subs: ['115', '117', '118', '119', '120'] | Test Subs: ['121', '122', '123', '125', '126']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.6968 | Val MAE: 2.1153
# Early stopping at epoch 154 (no improvement for 150 epochs)
# Fold 11 | Transformer | Validation: MAE=0.537, RMSE=0.681, R2=0.000
#
# Fold 12 | Validation Subs: ['127', '128', '129', '131', '133'] | Test Subs: ['134', '135', '136', '137', '138']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.7109 | Val MAE: 2.7928
# Early stopping at epoch 153 (no improvement for 150 epochs)
# Fold 12 | Transformer | Validation: MAE=0.677, RMSE=0.798, R2=0.000
#
# Fold 13 | Validation Subs: ['139', '140', '141', '142', '143'] | Test Subs: ['144', '145', '148', '149', '150']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.7045 | Val MAE: 2.6287
# Early stopping at epoch 155 (no improvement for 150 epochs)
# Fold 13 | Transformer | Validation: MAE=0.690, RMSE=0.810, R2=0.000
#
# Fold 14 | Validation Subs: ['151', '153', '154', '155', '156'] | Test Subs: ['157', '158', '159', '160', '162']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.6368 | Val MAE: 1.6190
# Early stopping at epoch 154 (no improvement for 150 epochs)
# Fold 14 | Transformer | Validation: MAE=0.851, RMSE=1.114, R2=0.000
#
# Fold 15 | Validation Subs: ['164', '165', '167', '168', '171'] | Test Subs: ['173', '174', '175', '179', '180', '183', '184', '185', '187', '188']
# Created 700 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.6447 | Val MAE: 2.9544
# Early stopping at epoch 154 (no improvement for 150 epochs)
# Fold 15 | Transformer | Validation: MAE=0.752, RMSE=0.834, R2=0.000
#
# Fold 16 | Validation Subs: ['6', '7', '8', '10', '11'] | Test Subs: ['1', '2', '3', '4', '5']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.6583 | Val MAE: 2.9996
# [Epoch 200/1000] Train MAE: 0.5137 | Val MAE: 2.0482
# [Epoch 300/1000] Train MAE: 0.4270 | Val MAE: 1.8825
# [Epoch 400/1000] Train MAE: 0.4381 | Val MAE: 2.6441
# Early stopping at epoch 491 (no improvement for 150 epochs)
# Fold 16 | Transformer | Validation: MAE=1.486, RMSE=2.015, R2=0.807
#
# Fold 17 | Validation Subs: ['19', '20', '21', '22', '23'] | Test Subs: ['13', '14', '15', '17', '18']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.6672 | Val MAE: 7.0072
# Early stopping at epoch 152 (no improvement for 150 epochs)
# Fold 17 | Transformer | Validation: MAE=3.643, RMSE=4.385, R2=-0.681
#
# Fold 18 | Validation Subs: ['29', '30', '31', '32', '33'] | Test Subs: ['24', '25', '26', '27', '28']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.5777 | Val MAE: 6.9708
# Early stopping at epoch 163 (no improvement for 150 epochs)
# Fold 18 | Transformer | Validation: MAE=5.065, RMSE=7.713, R2=-0.627
#
# Fold 19 | Validation Subs: ['40', '41', '42', '43', '45'] | Test Subs: ['34', '35', '36', '37', '38']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.5853 | Val MAE: 6.5040
# [Epoch 200/1000] Train MAE: 0.4762 | Val MAE: 6.4191
# [Epoch 300/1000] Train MAE: 0.4511 | Val MAE: 6.2483
# [Epoch 400/1000] Train MAE: 0.3911 | Val MAE: 6.2828
# Early stopping at epoch 421 (no improvement for 150 epochs)
# Fold 19 | Transformer | Validation: MAE=5.596, RMSE=6.815, R2=0.162
#
# Fold 20 | Validation Subs: ['52', '53', '54', '55', '56'] | Test Subs: ['46', '47', '48', '49', '51']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.6973 | Val MAE: 2.7387
# Early stopping at epoch 163 (no improvement for 150 epochs)
# Fold 20 | Transformer | Validation: MAE=1.129, RMSE=1.130, R2=0.000
#
# Fold 21 | Validation Subs: ['62', '63', '64', '65', '66'] | Test Subs: ['57', '58', '59', '60', '61']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.7315 | Val MAE: 1.6410
# Early stopping at epoch 165 (no improvement for 150 epochs)
# Fold 21 | Transformer | Validation: MAE=0.865, RMSE=1.029, R2=0.000
#
# Fold 22 | Validation Subs: ['72', '73', '74', '75', '76'] | Test Subs: ['67', '68', '69', '70', '71']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.6358 | Val MAE: 2.9841
# Early stopping at epoch 158 (no improvement for 150 epochs)
# Fold 22 | Transformer | Validation: MAE=0.707, RMSE=0.819, R2=0.000
#
# Fold 23 | Validation Subs: ['82', '83', '84', '85', '86'] | Test Subs: ['77', '78', '79', '80', '81']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.6456 | Val MAE: 2.0195
# Early stopping at epoch 154 (no improvement for 150 epochs)
# Fold 23 | Transformer | Validation: MAE=0.634, RMSE=0.744, R2=0.000
#
# Fold 24 | Validation Subs: ['94', '95', '97', '98', '99'] | Test Subs: ['87', '88', '89', '90', '92']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.6941 | Val MAE: 1.7734
# Early stopping at epoch 158 (no improvement for 150 epochs)
# Fold 24 | Transformer | Validation: MAE=0.727, RMSE=0.794, R2=0.000
#
# Fold 25 | Validation Subs: ['107', '109', '111', '112', '113'] | Test Subs: ['100', '102', '103', '105', '106']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.6560 | Val MAE: 2.6844
# Early stopping at epoch 160 (no improvement for 150 epochs)
# Fold 25 | Transformer | Validation: MAE=1.170, RMSE=1.175, R2=0.000
#
# Fold 26 | Validation Subs: ['121', '122', '123', '125', '126'] | Test Subs: ['115', '117', '118', '119', '120']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.6626 | Val MAE: 1.9989
# Early stopping at epoch 154 (no improvement for 150 epochs)
# Fold 26 | Transformer | Validation: MAE=0.807, RMSE=1.386, R2=0.000
#
# Fold 27 | Validation Subs: ['134', '135', '136', '137', '138'] | Test Subs: ['127', '128', '129', '131', '133']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.6382 | Val MAE: 1.8937
# Early stopping at epoch 160 (no improvement for 150 epochs)
# Fold 27 | Transformer | Validation: MAE=1.153, RMSE=1.205, R2=0.000
#
# Fold 28 | Validation Subs: ['144', '145', '148', '149', '150'] | Test Subs: ['139', '140', '141', '142', '143']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.6453 | Val MAE: 1.9961
# Early stopping at epoch 154 (no improvement for 150 epochs)
# Fold 28 | Transformer | Validation: MAE=0.691, RMSE=0.773, R2=0.000
#
# Fold 29 | Validation Subs: ['157', '158', '159', '160', '162'] | Test Subs: ['151', '153', '154', '155', '156']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.6307 | Val MAE: 2.4611
# Early stopping at epoch 156 (no improvement for 150 epochs)
# Fold 29 | Transformer | Validation: MAE=1.047, RMSE=1.152, R2=0.000
#
# Fold 30 | Validation Subs: ['173', '174', '175', '179', '180', '183', '184', '185', '187', '188'] | Test Subs: ['164', '165', '167', '168', '171']
# Created 700 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.6003 | Val MAE: 3.5653
# Early stopping at epoch 156 (no improvement for 150 epochs)
# Fold 30 | Transformer | Validation: MAE=1.212, RMSE=1.691, R2=0.000
#
#
# === Validation Performance (across all folds) ===
#                   MAE      RMSE        R2  Pearson r     Pearson p
# Transformer  1.658575  2.848634  0.734284   0.878102  7.635340e-51
#
# === Test Performance (across all folds) ===
#                   MAE      RMSE        R2  Pearson r     Pearson p
# Transformer  2.387556  3.925365  0.495449   0.764135  6.197849e-31

# %%
from ci import *

ci_results = {}

name = "Transformer"

ci_results[name] = subject_bootstrap_ci(
    all_results_test[name]['targets'],
    all_results_test[name]['preds'],
    all_results_test[name]['subjects'])

pd.DataFrame(ci_results['Transformer'])
# Out:
#                  MAE            RMSE             R2       Pearson r
# mean        2.387556        3.925365       0.495449        0.764135
# ci    [2.004, 2.771]  [3.189, 4.496]  [0.294, 0.66]  [0.688, 0.844]

# %% [markdown]
# ## Loading Lesion Left Classification Data

# %%
save_dir = 'data_clf'
loaded_dir = 'csv_clf'
# preprocess_and_save_data(loaded_dir, save_dir)
all_files = filter_valid_files(os.listdir(loaded_dir))
participant_ids = sorted({re.search(r'ID(\d+)_', f).group(1) for f in all_files}, key=lambda x: int(x))

# %% [markdown]
# ## Classification Evaluation Function

# %%
def evaluate_model_clf(model, test_loader, n_select_gaits, num_classes=3):
    """Classification evaluation: aggregate unit-level predictions per participant (majority vote)."""
    model.eval()
    device = next(model.parameters()).device

    t = []
    p = []

    with torch.no_grad():
        for batch in test_loader:
            if len(batch) == 3:
                x_load_list, y_batch, _ = batch
            else:
                x_load_list, y_batch = batch

            for i, x_load_sample in enumerate(x_load_list):
                x_task = x_load_sample[:6]
                num_units = len(x_task) - n_select_gaits + 1

                unit_preds = []

                for start_idx in range(num_units):
                    unit = x_task[start_idx:start_idx + n_select_gaits]
                    unit_tensor = unit.unsqueeze(0).to(device)

                    logits = model(unit_tensor)
                    pred_class = logits.argmax(dim=1).item()
                    unit_preds.append(pred_class)

                participant_target = y_batch[i].item()
                participant_pred = int(np.bincount(unit_preds).argmax())

                t.append(participant_target)
                p.append(participant_pred)

    return t, p

# %% [markdown]
# ## Classification Model Training Function

# %%
def train_model_clf(model, train_loader, experiment_seed=42, num_epochs=1000, N_gaits=2, val_loader=None, patience=50, num_classes=3):
    set_deterministic(experiment_seed)
    random.seed(experiment_seed)
    np.random.seed(experiment_seed)

    all_x = []
    all_y = []

    for batch in train_loader:
        if len(batch) == 3:
            x_load_list, y_batch, _ = batch
        else:
            x_load_list, y_batch = batch
        all_x.extend(x_load_list)
        all_y.extend(y_batch)

    optimized_train_loader = create_gait_units_dataloader(all_x, all_y, N_gaits=N_gaits,
                                                          batch_size=bsize, shuffle=True)

    val_unit_loader = None
    if val_loader is not None:
        val_x, val_y = [], []
        for batch in val_loader:
            if len(batch) == 3:
                x_load_list, y_batch, _ = batch
            else:
                x_load_list, y_batch = batch
            val_x.extend(x_load_list)
            val_y.extend(y_batch)
        val_unit_loader = create_gait_units_dataloader(val_x, val_y, N_gaits=N_gaits,
                                                       batch_size=bsize, shuffle=False)

    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-4)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=num_epochs)

    best_val_loss = float('inf')
    best_state = None
    epochs_no_improve = 0

    print("Starting training...")
    for epoch in range(num_epochs):
        model.train()
        total_loss = 0

        for x_batch, y_batch in optimized_train_loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device).long()

            logits = model(x_batch)
            loss = F.cross_entropy(logits, y_batch)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        scheduler.step()

        if val_unit_loader is not None:
            model.eval()
            val_loss_sum, val_n = 0.0, 0
            with torch.no_grad():
                for x_batch, y_batch in val_unit_loader:
                    x_batch = x_batch.to(device)
                    y_batch = y_batch.to(device).long()
                    logits = model(x_batch)
                    val_loss_sum += F.cross_entropy(logits, y_batch, reduction='sum').item()
                    val_n += x_batch.size(0)
            val_loss = val_loss_sum / val_n
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                best_state = {k: v.cpu().clone() for k, v in model.state_dict().items()}
                epochs_no_improve = 0
            else:
                epochs_no_improve += 1
            if epochs_no_improve >= patience:
                print(f"Early stopping at epoch {epoch + 1} (no improvement for {patience} epochs)")
                if best_state is not None:
                    model.load_state_dict(best_state)
                break

        if (epoch + 1) % 100 == 0:
            avg_loss = total_loss / len(optimized_train_loader)
            msg = f"[Epoch {epoch + 1}/{num_epochs}] Train CE loss: {avg_loss:.4f}"
            if val_unit_loader is not None:
                val_t, val_p = evaluate_model_clf(model, val_loader, n_select_gaits=N_gaits, num_classes=num_classes)
                val_acc = np.mean(np.array(val_t) == np.array(val_p))
                msg += f" | Val CE loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}"
            print(msg)

    if val_loader is not None and best_state is not None:
        model.load_state_dict(best_state)
    return model

# %% [markdown]
# ## Transformer Training Classification

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from val_test import val_test

n_folds = 30
models_clf = {'Transformer': []}
name = list(models_clf.keys())[0]

all_results_validation_clf = {name: {'targets': [], 'preds': []}}
all_results_test_clf = {name: {'targets': [], 'preds': [], 'subjects': []}}

for k in tqdm(range(n_folds)):

    model = Transformer(N_gaits=2, output_dim=3).to(device)

    validation_pids, test_pids = val_test(participant_ids, k)
    print(f"Fold {k+1} | Validation Subs: {validation_pids} | Test Subs: {test_pids}")

    train_loader, val_loader, test_loader = cv_data_create(validation_pids, test_pids, save_dir, batch_size=bsize)
    trained_model = train_model_clf(model, train_loader, experiment_seed=k, num_epochs=1000, N_gaits=2,
                                    val_loader=val_loader, patience=150, num_classes=3)

    val_t, val_p = evaluate_model_clf(trained_model, val_loader, n_select_gaits=2, num_classes=3)
    test_t, test_p = evaluate_model_clf(trained_model, test_loader, n_select_gaits=2, num_classes=3)

    all_results_validation_clf[name]['targets'].extend(val_t)
    all_results_validation_clf[name]['preds'].extend(val_p)

    all_results_test_clf[name]['targets'].extend(test_t)
    all_results_test_clf[name]['preds'].extend(test_p)
    all_results_test_clf[name]['subjects'].extend(test_pids)

    acc_val = accuracy_score(val_t, val_p)
    f1m_val = f1_score(val_t, val_p, average='macro')
    print(f"Fold {k + 1:02d} | {name} | Validation: Acc={acc_val:.3f}, F1-macro={f1m_val:.3f}\n")

# Overall pooled (OOF) metrics across all folds
val_t_all = np.array(all_results_validation_clf[name]['targets'])
val_p_all = np.array(all_results_validation_clf[name]['preds'])
test_t_all = np.array(all_results_test_clf[name]['targets'])
test_p_all = np.array(all_results_test_clf[name]['preds'])

def classification_metrics(t, p):
    return {
        'Accuracy': accuracy_score(t, p),
        'F1 (weighted)': f1_score(t, p, average='weighted'),
        'F1 (macro)': f1_score(t, p, average='macro'),
        'Precision (weighted)': precision_score(t, p, average='weighted', zero_division=0),
        'Precision (macro)': precision_score(t, p, average='macro', zero_division=0),
        'Recall (weighted)': recall_score(t, p, average='weighted', zero_division=0),
        'Recall (macro)': recall_score(t, p, average='macro', zero_division=0),
    }

results_val = classification_metrics(val_t_all, val_p_all)
results_test = classification_metrics(test_t_all, test_p_all)

print("\n=== Validation Performance (across all folds) ===")
print(pd.DataFrame({name: results_val}).T)

print("\n=== Test Performance (across all folds) ===")
results_test_df = pd.DataFrame({name: results_test}).T
results_test_df
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Fold 1 | Validation Subs: ['1', '2', '3', '4', '5'] | Test Subs: ['6', '7', '8', '10', '11']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0002 | Val CE loss: 5.0363 | Val Acc: 0.6000
# Early stopping at epoch 151 (no improvement for 150 epochs)
# Fold 01 | Transformer | Validation: Acc=0.000, F1-macro=0.000
#
# Fold 2 | Validation Subs: ['13', '14', '15', '17', '18'] | Test Subs: ['19', '20', '21', '22', '23']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0002 | Val CE loss: 6.9715 | Val Acc: 0.4000
# Early stopping at epoch 158 (no improvement for 150 epochs)
# Fold 02 | Transformer | Validation: Acc=0.600, F1-macro=0.444
#
# Fold 3 | Validation Subs: ['24', '25', '26', '27', '28'] | Test Subs: ['29', '30', '31', '32', '33']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0004 | Val CE loss: 4.1883 | Val Acc: 0.6000
# Early stopping at epoch 158 (no improvement for 150 epochs)
# Fold 03 | Transformer | Validation: Acc=0.600, F1-macro=0.583
#
# Fold 4 | Validation Subs: ['34', '35', '36', '37', '38'] | Test Subs: ['40', '41', '42', '43', '45']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0002 | Val CE loss: 2.3045 | Val Acc: 0.6000
# Early stopping at epoch 176 (no improvement for 150 epochs)
# Fold 04 | Transformer | Validation: Acc=0.800, F1-macro=0.800
#
# Fold 5 | Validation Subs: ['46', '47', '48', '49', '51'] | Test Subs: ['52', '53', '54', '55', '56']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0006 | Val CE loss: 0.6008 | Val Acc: 0.8000
# Early stopping at epoch 168 (no improvement for 150 epochs)
# Fold 05 | Transformer | Validation: Acc=0.800, F1-macro=0.822
#
# Fold 6 | Validation Subs: ['57', '58', '59', '60', '61'] | Test Subs: ['62', '63', '64', '65', '66']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0006 | Val CE loss: 0.0001 | Val Acc: 1.0000
# Early stopping at epoch 180 (no improvement for 150 epochs)
# Fold 06 | Transformer | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 7 | Validation Subs: ['67', '68', '69', '70', '71'] | Test Subs: ['72', '73', '74', '75', '76']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0004 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 200/1000] Train CE loss: 0.0001 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 300/1000] Train CE loss: 0.0000 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 400/1000] Train CE loss: 0.0001 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 500/1000] Train CE loss: 0.0001 | Val CE loss: 0.0000 | Val Acc: 1.0000
# Early stopping at epoch 510 (no improvement for 150 epochs)
# Fold 07 | Transformer | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 8 | Validation Subs: ['77', '78', '79', '80', '81'] | Test Subs: ['82', '83', '84', '85', '86']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0003 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 200/1000] Train CE loss: 0.0007 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 300/1000] Train CE loss: 0.0012 | Val CE loss: 0.0000 | Val Acc: 1.0000
# Early stopping at epoch 383 (no improvement for 150 epochs)
# Fold 08 | Transformer | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 9 | Validation Subs: ['87', '88', '89', '90', '92'] | Test Subs: ['94', '95', '97', '98', '99']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0005 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 200/1000] Train CE loss: 0.0008 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 300/1000] Train CE loss: 0.0001 | Val CE loss: 0.0000 | Val Acc: 1.0000
# Early stopping at epoch 348 (no improvement for 150 epochs)
# Fold 09 | Transformer | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 10 | Validation Subs: ['100', '102', '103', '105', '106'] | Test Subs: ['107', '109', '111', '112', '113']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0004 | Val CE loss: 0.8649 | Val Acc: 0.8000
# [Epoch 200/1000] Train CE loss: 0.0001 | Val CE loss: 0.7764 | Val Acc: 0.8000
# Early stopping at epoch 203 (no improvement for 150 epochs)
# Fold 10 | Transformer | Validation: Acc=0.800, F1-macro=0.444
#
# Fold 11 | Validation Subs: ['115', '117', '118', '119', '120'] | Test Subs: ['121', '122', '123', '125', '126']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0003 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 200/1000] Train CE loss: 0.0094 | Val CE loss: 0.3264 | Val Acc: 1.0000
# [Epoch 300/1000] Train CE loss: 0.0002 | Val CE loss: 0.0000 | Val Acc: 1.0000
# Early stopping at epoch 394 (no improvement for 150 epochs)
# Fold 11 | Transformer | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 12 | Validation Subs: ['127', '128', '129', '131', '133'] | Test Subs: ['134', '135', '136', '137', '138']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0004 | Val CE loss: 0.0000 | Val Acc: 1.0000
# Early stopping at epoch 196 (no improvement for 150 epochs)
# Fold 12 | Transformer | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 13 | Validation Subs: ['139', '140', '141', '142', '143'] | Test Subs: ['144', '145', '148', '149', '150']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0003 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 200/1000] Train CE loss: 0.0002 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 300/1000] Train CE loss: 0.0001 | Val CE loss: 0.0000 | Val Acc: 1.0000
# Early stopping at epoch 319 (no improvement for 150 epochs)
# Fold 13 | Transformer | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 14 | Validation Subs: ['151', '153', '154', '155', '156'] | Test Subs: ['157', '158', '159', '160', '162']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0003 | Val CE loss: 0.0068 | Val Acc: 1.0000
# [Epoch 200/1000] Train CE loss: 0.0002 | Val CE loss: 0.0182 | Val Acc: 1.0000
# Early stopping at epoch 204 (no improvement for 150 epochs)
# Fold 14 | Transformer | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 15 | Validation Subs: ['164', '165', '167', '168', '171'] | Test Subs: ['173', '174', '175', '179', '180', '183', '184', '185', '187', '188']
# Created 700 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0003 | Val CE loss: 0.0231 | Val Acc: 1.0000
# [Epoch 200/1000] Train CE loss: 0.0023 | Val CE loss: 0.0087 | Val Acc: 1.0000
# [Epoch 300/1000] Train CE loss: 0.0001 | Val CE loss: 0.0142 | Val Acc: 1.0000
# Early stopping at epoch 346 (no improvement for 150 epochs)
# Fold 15 | Transformer | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 16 | Validation Subs: ['6', '7', '8', '10', '11'] | Test Subs: ['1', '2', '3', '4', '5']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0002 | Val CE loss: 6.2198 | Val Acc: 0.4000
# Early stopping at epoch 152 (no improvement for 150 epochs)
# Fold 16 | Transformer | Validation: Acc=0.600, F1-macro=0.250
#
# Fold 17 | Validation Subs: ['19', '20', '21', '22', '23'] | Test Subs: ['13', '14', '15', '17', '18']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0006 | Val CE loss: 6.2991 | Val Acc: 0.4000
# Early stopping at epoch 152 (no improvement for 150 epochs)
# Fold 17 | Transformer | Validation: Acc=0.600, F1-macro=0.433
#
# Fold 18 | Validation Subs: ['29', '30', '31', '32', '33'] | Test Subs: ['24', '25', '26', '27', '28']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0003 | Val CE loss: 0.7881 | Val Acc: 0.8000
# Early stopping at epoch 172 (no improvement for 150 epochs)
# Fold 18 | Transformer | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 19 | Validation Subs: ['40', '41', '42', '43', '45'] | Test Subs: ['34', '35', '36', '37', '38']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0002 | Val CE loss: 4.9703 | Val Acc: 0.6000
# Early stopping at epoch 152 (no improvement for 150 epochs)
# Fold 19 | Transformer | Validation: Acc=0.600, F1-macro=0.375
#
# Fold 20 | Validation Subs: ['52', '53', '54', '55', '56'] | Test Subs: ['46', '47', '48', '49', '51']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0008 | Val CE loss: 0.0835 | Val Acc: 1.0000
# [Epoch 200/1000] Train CE loss: 0.0001 | Val CE loss: 0.0138 | Val Acc: 1.0000
# Early stopping at epoch 295 (no improvement for 150 epochs)
# Fold 20 | Transformer | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 21 | Validation Subs: ['62', '63', '64', '65', '66'] | Test Subs: ['57', '58', '59', '60', '61']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0004 | Val CE loss: 0.0461 | Val Acc: 1.0000
# Early stopping at epoch 173 (no improvement for 150 epochs)
# Fold 21 | Transformer | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 22 | Validation Subs: ['72', '73', '74', '75', '76'] | Test Subs: ['67', '68', '69', '70', '71']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0002 | Val CE loss: 0.2216 | Val Acc: 1.0000
# Early stopping at epoch 193 (no improvement for 150 epochs)
# Fold 22 | Transformer | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 23 | Validation Subs: ['82', '83', '84', '85', '86'] | Test Subs: ['77', '78', '79', '80', '81']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0004 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 200/1000] Train CE loss: 0.0001 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 300/1000] Train CE loss: 0.0002 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 400/1000] Train CE loss: 0.0001 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 500/1000] Train CE loss: 0.0001 | Val CE loss: 0.0000 | Val Acc: 1.0000
# Early stopping at epoch 540 (no improvement for 150 epochs)
# Fold 23 | Transformer | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 24 | Validation Subs: ['94', '95', '97', '98', '99'] | Test Subs: ['87', '88', '89', '90', '92']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0002 | Val CE loss: 0.0000 | Val Acc: 1.0000
# Early stopping at epoch 189 (no improvement for 150 epochs)
# Fold 24 | Transformer | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 25 | Validation Subs: ['107', '109', '111', '112', '113'] | Test Subs: ['100', '102', '103', '105', '106']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0002 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 200/1000] Train CE loss: 0.0002 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 300/1000] Train CE loss: 0.0002 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 400/1000] Train CE loss: 0.0001 | Val CE loss: 0.0000 | Val Acc: 1.0000
# Early stopping at epoch 496 (no improvement for 150 epochs)
# Fold 25 | Transformer | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 26 | Validation Subs: ['121', '122', '123', '125', '126'] | Test Subs: ['115', '117', '118', '119', '120']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0003 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 200/1000] Train CE loss: 0.0003 | Val CE loss: 0.0000 | Val Acc: 1.0000
# Early stopping at epoch 292 (no improvement for 150 epochs)
# Fold 26 | Transformer | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 27 | Validation Subs: ['134', '135', '136', '137', '138'] | Test Subs: ['127', '128', '129', '131', '133']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0009 | Val CE loss: 0.0050 | Val Acc: 1.0000
# [Epoch 200/1000] Train CE loss: 0.0001 | Val CE loss: 0.0004 | Val Acc: 1.0000
# Early stopping at epoch 234 (no improvement for 150 epochs)
# Fold 27 | Transformer | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 28 | Validation Subs: ['144', '145', '148', '149', '150'] | Test Subs: ['139', '140', '141', '142', '143']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0003 | Val CE loss: 0.0000 | Val Acc: 1.0000
# Early stopping at epoch 197 (no improvement for 150 epochs)
# Fold 28 | Transformer | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 29 | Validation Subs: ['157', '158', '159', '160', '162'] | Test Subs: ['151', '153', '154', '155', '156']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0002 | Val CE loss: 0.0823 | Val Acc: 1.0000
# [Epoch 200/1000] Train CE loss: 0.0001 | Val CE loss: 0.0118 | Val Acc: 1.0000
# Early stopping at epoch 281 (no improvement for 150 epochs)
# Fold 29 | Transformer | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 30 | Validation Subs: ['173', '174', '175', '179', '180', '183', '184', '185', '187', '188'] | Test Subs: ['164', '165', '167', '168', '171']
# Created 700 gait windows
# Created 50 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0005 | Val CE loss: 0.6494 | Val Acc: 0.9000
# Early stopping at epoch 160 (no improvement for 150 epochs)
# Fold 30 | Transformer | Validation: Acc=1.000, F1-macro=1.000
#
#
# === Validation Performance (across all folds) ===
#              Accuracy  F1 (weighted)  F1 (macro)  Precision (weighted)  \
# Transformer  0.883871       0.876319    0.729683              0.872639
#
#              Precision (macro)  Recall (weighted)  Recall (macro)
# Transformer            0.76339           0.883871        0.706521
#
# === Test Performance (across all folds) ===
#              Accuracy  F1 (weighted)  F1 (macro)  Precision (weighted)  \
# Transformer  0.812903       0.814609    0.626054               0.81702
#
#              Precision (macro)  Recall (weighted)  Recall (macro)
# Transformer           0.625008           0.812903        0.628357

# %%
from ci_class import subject_bootstrap_ci_class

ci_results = {}

name = "Transformer"

ci_results[name] = subject_bootstrap_ci_class(
    all_results_test_clf[name]['targets'],
    all_results_test_clf[name]['preds'],
    all_results_test_clf[name]['subjects'])

pd.DataFrame(ci_results['Transformer'])
# Out:
#             Accuracy   F1 (weighted)      F1 (macro) Precision (weighted)  \
# mean        0.812903        0.814609        0.626054              0.81702
# ci    [0.765, 0.861]  [0.767, 0.863]  [0.535, 0.704]       [0.769, 0.871]
#
#      Precision (macro) Recall (weighted)  Recall (macro)
# mean          0.625008          0.812903        0.628357
# ci      [0.536, 0.716]    [0.765, 0.861]  [0.538, 0.715]
