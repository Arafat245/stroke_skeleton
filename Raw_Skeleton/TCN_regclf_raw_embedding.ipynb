# %%
import os
import re
import random
import numpy as np
import pandas as pd
import torch
import time
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from tqdm.notebook import tqdm

from data_utils_load import *
from tcn import TCN

device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')

def filter_valid_files(file_list):
    valid_files = []
    for file in file_list:
        file = file.strip()
        if re.match(r'^ID\d+_\d+\.csv$', file):
            valid_files.append(file)
    return valid_files

def set_deterministic(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

bsize = 64

# %% [markdown]
# ## Loading POMA Data

# %%
save_dir = '/mnt/sdb/arafat/stroke_riemann/data'
loaded_dir = '/mnt/sdb/arafat/stroke_riemann/csv_r'
# preprocess_and_save_data(loaded_dir, save_dir)
all_files = filter_valid_files(os.listdir(loaded_dir))
participant_ids = sorted({re.search(r'ID(\d+)_', f).group(1) for f in all_files}, key=lambda x: int(x))

# %% [markdown]
# ## Gait Unit Creation

# %%
class GaitUnitsDataset(Dataset):
    def __init__(self, x_load_list, y_batch, N_gaits):
        self.unit_samples = []
        self.unit_labels = []
        
        for x_task, y_task in zip(x_load_list, y_batch):
            L = x_task.size(0)
            num_units = L - N_gaits + 1
            units = [x_task[start:start + N_gaits] for start in range(num_units)]
            self.unit_samples.extend(units)
            self.unit_labels.extend([y_task] * num_units)
        print(f"Created {len(self.unit_samples)} gait windows")
    
    def __len__(self):
        return len(self.unit_samples)
    
    def __getitem__(self, idx):
        return self.unit_samples[idx], self.unit_labels[idx]


def create_gait_units_dataloader(x_load_list, y_batch, N_gaits, batch_size=64, shuffle=True):
    dataset = GaitUnitsDataset(x_load_list, y_batch, N_gaits)
    return DataLoader(dataset, batch_size=batch_size, shuffle=shuffle)

# %% [markdown]
# ## Regression Evaluation Function

# %%
def evaluate_model(model, test_loader, n_select_gaits):

    model.eval()
    device = next(model.parameters()).device

    t = []
    p = []

    with torch.no_grad():
        for batch in test_loader:
            if len(batch) == 3:
                x_load_list, y_batch, _ = batch
            else:
                x_load_list, y_batch = batch

            for i, x_load_sample in enumerate(x_load_list):
                x_task = x_load_sample[:6]
                num_units = len(x_task) - n_select_gaits + 1

                unit_preds = []
                    
                for start_idx in range(num_units):
                    unit = x_task[start_idx:start_idx + n_select_gaits]
                    unit_tensor = unit.unsqueeze(0).to(device)
                    y_target = y_batch[i:i+1].to(device)
                        
                    y_pred = model(unit_tensor)
                    unit_preds.append(y_pred.item())

                participant_target = y_target.item()
                participant_pred = float(np.median(np.array(unit_preds)))

                t.append(participant_target)
                p.append(participant_pred)
    
    return t, p

# %% [markdown]
# ## Regression Model Training Function

# %%
def train_model(model, train_loader, experiment_seed=42, num_epochs=1000, N_gaits=2, val_loader=None, patience=50):
    set_deterministic(experiment_seed)
    random.seed(experiment_seed)
    np.random.seed(experiment_seed)

    all_x = []
    all_y = []
    
    for batch in train_loader:
        if len(batch) == 3:
            x_load_list, y_batch, _ = batch
        else:
            x_load_list, y_batch = batch
        all_x.extend(x_load_list)
        all_y.extend(y_batch)
    
    optimized_train_loader = create_gait_units_dataloader(all_x, all_y, N_gaits=N_gaits, 
                                                          batch_size=bsize, shuffle=True)
    
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-4)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=num_epochs)

    best_val_mae = float('inf')
    best_state = None
    epochs_no_improve = 0

    print("Starting training...")
    for epoch in range(num_epochs):
        model.train()
        total_loss = 0
        
        for x_batch, y_batch in optimized_train_loader:
            x_batch = x_batch.to(device) 
            y_batch = y_batch.to(device)  
            
            y_pred = model(x_batch).view(-1)
            loss = F.l1_loss(y_pred, y_batch)
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        
        scheduler.step()

        if val_loader is not None:
            val_t, val_p = evaluate_model(model, val_loader, n_select_gaits=N_gaits)
            val_mae = np.mean(np.abs(np.array(val_t) - np.array(val_p)))
            if val_mae < best_val_mae:
                best_val_mae = val_mae
                best_state = {k: v.cpu().clone() for k, v in model.state_dict().items()}
                epochs_no_improve = 0
            else:
                epochs_no_improve += 1
            if epochs_no_improve >= patience:
                print(f"Early stopping at epoch {epoch + 1} (no improvement for {patience} epochs)")
                if best_state is not None:
                    model.load_state_dict(best_state)
                break
        
        if (epoch + 1) % 100 == 0:
            avg_loss = total_loss / len(optimized_train_loader)
            msg = f"[Epoch {epoch + 1}/{num_epochs}] Train MAE: {avg_loss:.4f}"
            if val_loader is not None:
                msg += f" | Val MAE: {val_mae:.4f}"
            print(msg)

    if val_loader is not None and best_state is not None:
        model.load_state_dict(best_state)
    return model

# %% [markdown]
# ## TCN Regressor Training

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import StandardScaler
from val_test import val_test
from print_results import print_results_regression


def extract_unit_embedding(model, unit_tensor):
    """Extract embedding from the TCN penultimate representation."""
    B, G, T, C = unit_tensor.shape
    x = unit_tensor.reshape(B, G * T, C)
    x = x.permute(0, 2, 1)
    tcn_out = model.network(x)
    tcn_out = tcn_out.permute(0, 2, 1)
    feat = model.act(tcn_out)
    feat = feat.reshape(feat.shape[0], -1)
    return feat


def build_participant_embeddings(model, data_loader, n_select_gaits=2):
    """Create one embedding per participant by median pooling unit embeddings."""
    model.eval()

    emb_list = []
    targets = []
    subjects = []

    with torch.no_grad():
        for batch in data_loader:
            if len(batch) == 3:
                x_load_list, y_batch, pid_batch = batch
            else:
                x_load_list, y_batch = batch
                pid_batch = [None] * len(x_load_list)

            for i, x_load_sample in enumerate(x_load_list):
                x_task = x_load_sample[:6]
                num_units = len(x_task) - n_select_gaits + 1

                unit_embs = []
                for start_idx in range(num_units):
                    unit = x_task[start_idx:start_idx + n_select_gaits]
                    unit_tensor = unit.unsqueeze(0).to(device)
                    emb = extract_unit_embedding(model, unit_tensor)
                    unit_embs.append(emb.squeeze(0).cpu().numpy())

                participant_emb = np.median(np.array(unit_embs), axis=0)
                emb_list.append(participant_emb)
                targets.append(float(y_batch[i].item()))
                subjects.append(pid_batch[i] if pid_batch[i] is not None else None)

    X = np.array(emb_list, dtype=np.float32)
    y = np.array(targets, dtype=np.float32)
    return X, y, subjects


n_folds = 30
n_select_gaits = 2
models = {'TCN+KNN': []}
name = list(models.keys())[0]
all_results_validation = {name: {'targets': [], 'preds': []}}
all_results_test = {name: {'targets': [], 'preds': [], 'subjects': []}}

for k in tqdm(range(n_folds)):

    model = TCN(N_gaits=n_select_gaits).to(device)

    validation_pids, test_pids = val_test(participant_ids, k)
    print(f"Fold {k+1} | Validation Subs: {validation_pids} | Test Subs: {test_pids}")

    train_loader, val_loader, test_loader = cv_data_create(validation_pids, test_pids, save_dir, batch_size=bsize)

    # 1) Train TCN regressor
    trained_model = train_model(
        model,
        train_loader,
        experiment_seed=k,
        val_loader=val_loader,
        patience=200,
        N_gaits=n_select_gaits,
    )

    # 2) Extract participant-level embeddings from trained TCN
    X_train, y_train, _ = build_participant_embeddings(trained_model, train_loader, n_select_gaits=n_select_gaits)
    X_val, y_val, _ = build_participant_embeddings(trained_model, val_loader, n_select_gaits=n_select_gaits)
    X_test, y_test, test_subjects = build_participant_embeddings(trained_model, test_loader, n_select_gaits=n_select_gaits)

    # 3) KNN regression in embedding space
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_val = scaler.transform(X_val)
    X_test = scaler.transform(X_test)

    knn = KNeighborsRegressor(n_neighbors=5, weights='distance')
    knn.fit(X_train, y_train)

    val_p = knn.predict(X_val)
    test_p = knn.predict(X_test)

    all_results_validation[name]['targets'].extend(y_val.tolist())
    all_results_validation[name]['preds'].extend(val_p.tolist())
    all_results_test[name]['targets'].extend(y_test.tolist())
    all_results_test[name]['preds'].extend(test_p.tolist())
    all_results_test[name]['subjects'].extend(test_subjects)

    mae_val = mean_absolute_error(y_val, val_p)
    rmse_val = np.sqrt(mean_squared_error(y_val, val_p))
    r2_val = r2_score(y_val, val_p)
    print(f"Fold {k + 1:02d} | {name} | Validation: MAE={mae_val:.3f}, RMSE={rmse_val:.3f}, R2={r2_val:.3f}\\n")

test_results_df = print_results_regression(all_results_validation, all_results_test, models)
test_results_df
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Fold 1 | Validation Subs: ['1', '2', '3', '4', '5'] | Test Subs: ['6', '7', '8', '10', '11']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 1.0732 | Val MAE: 5.0094
# [Epoch 200/1000] Train MAE: 0.8007 | Val MAE: 5.1907
# Early stopping at epoch 224 (no improvement for 200 epochs)
# Fold 01 | TCN+KNN | Validation: MAE=3.473, RMSE=4.128, R2=0.290\n
# Fold 2 | Validation Subs: ['13', '14', '15', '17', '18'] | Test Subs: ['19', '20', '21', '22', '23']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.8948 | Val MAE: 3.3268
# [Epoch 200/1000] Train MAE: 0.8815 | Val MAE: 3.9683
# Early stopping at epoch 229 (no improvement for 200 epochs)
# Fold 02 | TCN+KNN | Validation: MAE=8.512, RMSE=9.035, R2=-5.803\n
# Fold 3 | Validation Subs: ['24', '25', '26', '27', '28'] | Test Subs: ['29', '30', '31', '32', '33']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 1.0679 | Val MAE: 3.2315
# [Epoch 200/1000] Train MAE: 0.8685 | Val MAE: 3.1122
# Early stopping at epoch 220 (no improvement for 200 epochs)
# Fold 03 | TCN+KNN | Validation: MAE=5.824, RMSE=6.293, R2=-0.926\n
# Fold 4 | Validation Subs: ['34', '35', '36', '37', '38'] | Test Subs: ['40', '41', '42', '43', '45']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.9663 | Val MAE: 5.5983
# [Epoch 200/1000] Train MAE: 0.8613 | Val MAE: 5.5733
# [Epoch 300/1000] Train MAE: 0.8657 | Val MAE: 5.4061
# Early stopping at epoch 340 (no improvement for 200 epochs)
# Fold 04 | TCN+KNN | Validation: MAE=4.421, RMSE=5.881, R2=0.305\n
# Fold 5 | Validation Subs: ['46', '47', '48', '49', '51'] | Test Subs: ['52', '53', '54', '55', '56']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 1.0924 | Val MAE: 3.3954
# [Epoch 200/1000] Train MAE: 0.8996 | Val MAE: 2.9688
# Early stopping at epoch 214 (no improvement for 200 epochs)
# Fold 05 | TCN+KNN | Validation: MAE=2.214, RMSE=2.512, R2=0.794\n
# Fold 6 | Validation Subs: ['57', '58', '59', '60', '61'] | Test Subs: ['62', '63', '64', '65', '66']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 1.0505 | Val MAE: 2.8074
# [Epoch 200/1000] Train MAE: 0.8162 | Val MAE: 1.3290
# [Epoch 300/1000] Train MAE: 0.7459 | Val MAE: 1.9445
# [Epoch 400/1000] Train MAE: 0.6799 | Val MAE: 1.3314
# Early stopping at epoch 401 (no improvement for 200 epochs)
# Fold 06 | TCN+KNN | Validation: MAE=0.000, RMSE=0.000, R2=0.000\n
# Fold 7 | Validation Subs: ['67', '68', '69', '70', '71'] | Test Subs: ['72', '73', '74', '75', '76']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 1.0118 | Val MAE: 3.2339
# [Epoch 200/1000] Train MAE: 1.2703 | Val MAE: 3.7152
# [Epoch 300/1000] Train MAE: 0.7246 | Val MAE: 2.9303
# Early stopping at epoch 305 (no improvement for 200 epochs)
# Fold 07 | TCN+KNN | Validation: MAE=0.000, RMSE=0.000, R2=0.000\n
# Fold 8 | Validation Subs: ['77', '78', '79', '80', '81'] | Test Subs: ['82', '83', '84', '85', '86']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 1.0018 | Val MAE: 2.7651
# [Epoch 200/1000] Train MAE: 0.8284 | Val MAE: 2.9166
# [Epoch 300/1000] Train MAE: 0.7445 | Val MAE: 2.0064
# [Epoch 400/1000] Train MAE: 0.8347 | Val MAE: 1.9530
# [Epoch 500/1000] Train MAE: 0.6454 | Val MAE: 2.1418
# Early stopping at epoch 575 (no improvement for 200 epochs)
# Fold 08 | TCN+KNN | Validation: MAE=0.000, RMSE=0.000, R2=0.000\n
# Fold 9 | Validation Subs: ['87', '88', '89', '90', '92'] | Test Subs: ['94', '95', '97', '98', '99']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 1.0910 | Val MAE: 3.3236
# [Epoch 200/1000] Train MAE: 0.9233 | Val MAE: 1.5951
# [Epoch 300/1000] Train MAE: 0.8277 | Val MAE: 1.7273
# [Epoch 400/1000] Train MAE: 0.8036 | Val MAE: 2.4369
# Early stopping at epoch 426 (no improvement for 200 epochs)
# Fold 09 | TCN+KNN | Validation: MAE=0.039, RMSE=0.086, R2=0.000\n
# Fold 10 | Validation Subs: ['100', '102', '103', '105', '106'] | Test Subs: ['107', '109', '111', '112', '113']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 1.0978 | Val MAE: 4.0512
# [Epoch 200/1000] Train MAE: 0.9058 | Val MAE: 4.2113
# [Epoch 300/1000] Train MAE: 0.9413 | Val MAE: 3.9494
# Early stopping at epoch 357 (no improvement for 200 epochs)
# Fold 10 | TCN+KNN | Validation: MAE=1.434, RMSE=3.038, R2=0.000\n
# Fold 11 | Validation Subs: ['115', '117', '118', '119', '120'] | Test Subs: ['121', '122', '123', '125', '126']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 1.0065 | Val MAE: 2.5579
# [Epoch 200/1000] Train MAE: 0.9121 | Val MAE: 1.4648
# Early stopping at epoch 279 (no improvement for 200 epochs)
# Fold 11 | TCN+KNN | Validation: MAE=0.048, RMSE=0.107, R2=0.000\n
# Fold 12 | Validation Subs: ['127', '128', '129', '131', '133'] | Test Subs: ['134', '135', '136', '137', '138']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 1.1351 | Val MAE: 1.8361
# [Epoch 200/1000] Train MAE: 0.8810 | Val MAE: 1.7129
# [Epoch 300/1000] Train MAE: 0.8390 | Val MAE: 1.2712
# Early stopping at epoch 387 (no improvement for 200 epochs)
# Fold 12 | TCN+KNN | Validation: MAE=0.000, RMSE=0.000, R2=0.000\n
# Fold 13 | Validation Subs: ['139', '140', '141', '142', '143'] | Test Subs: ['144', '145', '148', '149', '150']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 1.0950 | Val MAE: 2.7966
# [Epoch 200/1000] Train MAE: 1.0548 | Val MAE: 2.5256
# [Epoch 300/1000] Train MAE: 0.7900 | Val MAE: 2.8767
# [Epoch 400/1000] Train MAE: 0.8108 | Val MAE: 2.3463
# Early stopping at epoch 405 (no improvement for 200 epochs)
# Fold 13 | TCN+KNN | Validation: MAE=0.000, RMSE=0.000, R2=0.000\n
# Fold 14 | Validation Subs: ['151', '153', '154', '155', '156'] | Test Subs: ['157', '158', '159', '160', '162']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 1.0357 | Val MAE: 2.2683
# [Epoch 200/1000] Train MAE: 0.9990 | Val MAE: 2.2180
# [Epoch 300/1000] Train MAE: 0.7800 | Val MAE: 2.7852
# [Epoch 400/1000] Train MAE: 0.7637 | Val MAE: 2.8998
# Early stopping at epoch 415 (no improvement for 200 epochs)
# Fold 14 | TCN+KNN | Validation: MAE=0.087, RMSE=0.195, R2=0.000\n
# Fold 15 | Validation Subs: ['164', '165', '167', '168', '171'] | Test Subs: ['173', '174', '175', '179', '180', '183', '184', '185', '187', '188']
# Created 700 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 1.1926 | Val MAE: 3.0454
# [Epoch 200/1000] Train MAE: 0.9921 | Val MAE: 3.9995
# Early stopping at epoch 299 (no improvement for 200 epochs)
# Fold 15 | TCN+KNN | Validation: MAE=0.000, RMSE=0.000, R2=0.000\n
# Fold 16 | Validation Subs: ['6', '7', '8', '10', '11'] | Test Subs: ['1', '2', '3', '4', '5']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 1.0676 | Val MAE: 4.7907
# [Epoch 200/1000] Train MAE: 0.8498 | Val MAE: 5.0517
# Early stopping at epoch 204 (no improvement for 200 epochs)
# Fold 16 | TCN+KNN | Validation: MAE=3.586, RMSE=5.482, R2=-0.428\n
# Fold 17 | Validation Subs: ['19', '20', '21', '22', '23'] | Test Subs: ['13', '14', '15', '17', '18']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.8580 | Val MAE: 5.1693
# [Epoch 200/1000] Train MAE: 0.9542 | Val MAE: 4.9505
# [Epoch 300/1000] Train MAE: 0.8471 | Val MAE: 4.9671
# Early stopping at epoch 309 (no improvement for 200 epochs)
# Fold 17 | TCN+KNN | Validation: MAE=6.771, RMSE=7.605, R2=-4.056\n
# Fold 18 | Validation Subs: ['29', '30', '31', '32', '33'] | Test Subs: ['24', '25', '26', '27', '28']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 1.0074 | Val MAE: 4.7492
# [Epoch 200/1000] Train MAE: 0.8941 | Val MAE: 4.9354
# Early stopping at epoch 212 (no improvement for 200 epochs)
# Fold 18 | TCN+KNN | Validation: MAE=8.030, RMSE=9.547, R2=-1.493\n
# Fold 19 | Validation Subs: ['40', '41', '42', '43', '45'] | Test Subs: ['34', '35', '36', '37', '38']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 1.0245 | Val MAE: 7.5409
# [Epoch 200/1000] Train MAE: 0.8353 | Val MAE: 7.5257
# Early stopping at epoch 203 (no improvement for 200 epochs)
# Fold 19 | TCN+KNN | Validation: MAE=5.916, RMSE=6.573, R2=0.221\n
# Fold 20 | Validation Subs: ['52', '53', '54', '55', '56'] | Test Subs: ['46', '47', '48', '49', '51']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 1.0855 | Val MAE: 2.5809
# [Epoch 200/1000] Train MAE: 0.9095 | Val MAE: 1.5511
# [Epoch 300/1000] Train MAE: 0.8005 | Val MAE: 1.6491
# Early stopping at epoch 322 (no improvement for 200 epochs)
# Fold 20 | TCN+KNN | Validation: MAE=0.344, RMSE=0.603, R2=0.000\n
# Fold 21 | Validation Subs: ['62', '63', '64', '65', '66'] | Test Subs: ['57', '58', '59', '60', '61']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 1.0084 | Val MAE: 3.4307
# [Epoch 200/1000] Train MAE: 0.9202 | Val MAE: 2.8240
# [Epoch 300/1000] Train MAE: 0.8251 | Val MAE: 2.3999
# Early stopping at epoch 359 (no improvement for 200 epochs)
# Fold 21 | TCN+KNN | Validation: MAE=0.000, RMSE=0.000, R2=0.000\n
# Fold 22 | Validation Subs: ['72', '73', '74', '75', '76'] | Test Subs: ['67', '68', '69', '70', '71']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.9208 | Val MAE: 3.2553
# [Epoch 200/1000] Train MAE: 0.8674 | Val MAE: 2.6682
# [Epoch 300/1000] Train MAE: 0.7543 | Val MAE: 3.1619
# [Epoch 400/1000] Train MAE: 0.7297 | Val MAE: 3.7867
# Early stopping at epoch 401 (no improvement for 200 epochs)
# Fold 22 | TCN+KNN | Validation: MAE=0.284, RMSE=0.555, R2=0.000\n
# Fold 23 | Validation Subs: ['82', '83', '84', '85', '86'] | Test Subs: ['77', '78', '79', '80', '81']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.9515 | Val MAE: 1.8068
# [Epoch 200/1000] Train MAE: 0.8268 | Val MAE: 1.3333
# [Epoch 300/1000] Train MAE: 0.9071 | Val MAE: 1.7566
# [Epoch 400/1000] Train MAE: 0.7624 | Val MAE: 1.5241
# [Epoch 500/1000] Train MAE: 0.7397 | Val MAE: 1.8949
# Early stopping at epoch 510 (no improvement for 200 epochs)
# Fold 23 | TCN+KNN | Validation: MAE=0.000, RMSE=0.000, R2=0.000\n
# Fold 24 | Validation Subs: ['94', '95', '97', '98', '99'] | Test Subs: ['87', '88', '89', '90', '92']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.9830 | Val MAE: 2.3131
# [Epoch 200/1000] Train MAE: 0.8343 | Val MAE: 2.5249
# Early stopping at epoch 233 (no improvement for 200 epochs)
# Fold 24 | TCN+KNN | Validation: MAE=0.072, RMSE=0.162, R2=0.000\n
# Fold 25 | Validation Subs: ['107', '109', '111', '112', '113'] | Test Subs: ['100', '102', '103', '105', '106']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 1.0950 | Val MAE: 2.2443
# [Epoch 200/1000] Train MAE: 0.9658 | Val MAE: 2.1004
# Early stopping at epoch 290 (no improvement for 200 epochs)
# Fold 25 | TCN+KNN | Validation: MAE=0.000, RMSE=0.000, R2=0.000\n
# Fold 26 | Validation Subs: ['121', '122', '123', '125', '126'] | Test Subs: ['115', '117', '118', '119', '120']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 1.1774 | Val MAE: 2.6135
# [Epoch 200/1000] Train MAE: 0.9451 | Val MAE: 1.9743
# [Epoch 300/1000] Train MAE: 0.9241 | Val MAE: 2.1355
# [Epoch 400/1000] Train MAE: 0.7999 | Val MAE: 1.5988
# Early stopping at epoch 445 (no improvement for 200 epochs)
# Fold 26 | TCN+KNN | Validation: MAE=0.039, RMSE=0.087, R2=0.000\n
# Fold 27 | Validation Subs: ['134', '135', '136', '137', '138'] | Test Subs: ['127', '128', '129', '131', '133']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 0.9811 | Val MAE: 2.9203
# [Epoch 200/1000] Train MAE: 0.8878 | Val MAE: 3.4149
# [Epoch 300/1000] Train MAE: 0.9192 | Val MAE: 3.1068
# [Epoch 400/1000] Train MAE: 0.7368 | Val MAE: 3.0531
# Early stopping at epoch 416 (no improvement for 200 epochs)
# Fold 27 | TCN+KNN | Validation: MAE=0.000, RMSE=0.000, R2=0.000\n
# Fold 28 | Validation Subs: ['144', '145', '148', '149', '150'] | Test Subs: ['139', '140', '141', '142', '143']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 1.0728 | Val MAE: 1.9092
# [Epoch 200/1000] Train MAE: 1.0069 | Val MAE: 1.9035
# [Epoch 300/1000] Train MAE: 0.8482 | Val MAE: 1.5019
# [Epoch 400/1000] Train MAE: 0.9190 | Val MAE: 1.9009
# [Epoch 500/1000] Train MAE: 0.7257 | Val MAE: 1.6785
# [Epoch 600/1000] Train MAE: 0.6694 | Val MAE: 1.1073
# Early stopping at epoch 639 (no improvement for 200 epochs)
# Fold 28 | TCN+KNN | Validation: MAE=0.000, RMSE=0.000, R2=0.000\n
# Fold 29 | Validation Subs: ['157', '158', '159', '160', '162'] | Test Subs: ['151', '153', '154', '155', '156']
# Created 725 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 1.0177 | Val MAE: 1.7728
# [Epoch 200/1000] Train MAE: 0.9535 | Val MAE: 2.3834
# Early stopping at epoch 260 (no improvement for 200 epochs)
# Fold 29 | TCN+KNN | Validation: MAE=0.275, RMSE=0.614, R2=0.000\n
# Fold 30 | Validation Subs: ['173', '174', '175', '179', '180', '183', '184', '185', '187', '188'] | Test Subs: ['164', '165', '167', '168', '171']
# Created 700 gait windows
# Starting training...
# [Epoch 100/1000] Train MAE: 1.1406 | Val MAE: 3.9495
# [Epoch 200/1000] Train MAE: 0.8297 | Val MAE: 3.7768
# [Epoch 300/1000] Train MAE: 0.8255 | Val MAE: 4.0445
# [Epoch 400/1000] Train MAE: 0.6825 | Val MAE: 3.1665
# Early stopping at epoch 403 (no improvement for 200 epochs)
# Fold 30 | TCN+KNN | Validation: MAE=0.237, RMSE=0.687, R2=0.000\n
#
# === Validation Performance (across all folds) ===
#              MAE      RMSE        R2  Pearson r     Pearson p
# TCN+KNN  1.67238  3.648821  0.564037   0.795809  3.759609e-35
#
# === Test Performance (across all folds) ===
#               MAE      RMSE        R2  Pearson r     Pearson p
# TCN+KNN  1.703993  3.931599  0.493845    0.73238  2.529973e-27

# %%
from ci import *

ci_results = {}

name = "TCN+KNN"

ci_results[name] = subject_bootstrap_ci(
    all_results_test[name]['targets'],
    all_results_test[name]['preds'],
    all_results_test[name]['subjects'])

pd.DataFrame(ci_results[name])
# Out:
#                  MAE            RMSE              R2       Pearson r
# mean        1.703993        3.931599        0.493845         0.73238
# ci    [1.284, 2.123]  [3.175, 4.526]  [0.364, 0.624]  [0.635, 0.839]

# %% [markdown]
# ## Loading Lesion Left Classifcation Data

# %%
save_dir = 'data_clf'
loaded_dir = 'csv_clf'
preprocess_and_save_data(loaded_dir, save_dir)
all_files = filter_valid_files(os.listdir(loaded_dir))
participant_ids = sorted({re.search(r'ID(\d+)_', f).group(1) for f in all_files}, key=lambda x: int(x))
# Out:
# Global Average Loaded Gait Length: 100
# Preprocessed data saved to data_clf

# %% [markdown]
# ## Classification Evaluation Function

# %%
def evaluate_model_clf(model, test_loader, n_select_gaits, num_classes=3):
    """Classification evaluation: aggregate unit-level predictions per participant (majority vote)."""
    model.eval()
    device = next(model.parameters()).device

    t = []
    p = []

    with torch.no_grad():
        for batch in test_loader:
            if len(batch) == 3:
                x_load_list, y_batch, _ = batch
            else:
                x_load_list, y_batch = batch

            for i, x_load_sample in enumerate(x_load_list):
                x_task = x_load_sample[:6]
                num_units = len(x_task) - n_select_gaits + 1

                unit_preds = []

                for start_idx in range(num_units):
                    unit = x_task[start_idx:start_idx + n_select_gaits]
                    unit_tensor = unit.unsqueeze(0).to(device)

                    logits = model(unit_tensor)
                    pred_class = logits.argmax(dim=1).item()
                    unit_preds.append(pred_class)

                participant_target = y_batch[i].item()
                participant_pred = int(np.bincount(unit_preds).argmax())

                t.append(participant_target)
                p.append(participant_pred)

    return t, p

# %% [markdown]
# ## Classification Model Training Function

# %%
def train_model_clf(model, train_loader, experiment_seed=42, num_epochs=1000, N_gaits=2, val_loader=None, patience=50, num_classes=3):
    set_deterministic(experiment_seed)
    random.seed(experiment_seed)
    np.random.seed(experiment_seed)

    all_x = []
    all_y = []

    for batch in train_loader:
        if len(batch) == 3:
            x_load_list, y_batch, _ = batch
        else:
            x_load_list, y_batch = batch
        all_x.extend(x_load_list)
        all_y.extend(y_batch)

    optimized_train_loader = create_gait_units_dataloader(all_x, all_y, N_gaits=N_gaits,
                                                          batch_size=bsize, shuffle=True)

    val_unit_loader = None
    if val_loader is not None:
        val_x, val_y = [], []
        for batch in val_loader:
            if len(batch) == 3:
                x_load_list, y_batch, _ = batch
            else:
                x_load_list, y_batch = batch
            val_x.extend(x_load_list)
            val_y.extend(y_batch)
        val_unit_loader = create_gait_units_dataloader(val_x, val_y, N_gaits=N_gaits,
                                                       batch_size=bsize, shuffle=False)

    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-4)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=num_epochs)

    best_val_loss = float('inf')
    best_state = None
    epochs_no_improve = 0

    print("Starting training...")
    for epoch in range(num_epochs):
        model.train()
        total_loss = 0

        for x_batch, y_batch in optimized_train_loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device).long()

            logits = model(x_batch)
            loss = F.cross_entropy(logits, y_batch)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        scheduler.step()

        if val_unit_loader is not None:
            model.eval()
            val_loss_sum, val_n = 0.0, 0
            with torch.no_grad():
                for x_batch, y_batch in val_unit_loader:
                    x_batch = x_batch.to(device)
                    y_batch = y_batch.to(device).long()
                    logits = model(x_batch)
                    val_loss_sum += F.cross_entropy(logits, y_batch, reduction='sum').item()
                    val_n += x_batch.size(0)
            val_loss = val_loss_sum / val_n
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                best_state = {k: v.cpu().clone() for k, v in model.state_dict().items()}
                epochs_no_improve = 0
            else:
                epochs_no_improve += 1
            if epochs_no_improve >= patience:
                print(f"Early stopping at epoch {epoch + 1} (no improvement for {patience} epochs)")
                if best_state is not None:
                    model.load_state_dict(best_state)
                break

        if (epoch + 1) % 100 == 0:
            avg_loss = total_loss / len(optimized_train_loader)
            msg = f"[Epoch {epoch + 1}/{num_epochs}] Train CE loss: {avg_loss:.4f}"
            if val_unit_loader is not None:
                val_t, val_p = evaluate_model_clf(model, val_loader, n_select_gaits=N_gaits, num_classes=num_classes)
                val_acc = np.mean(np.array(val_t) == np.array(val_p))
                msg += f" | Val CE loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}"
            print(msg)

    if val_loader is not None and best_state is not None:
        model.load_state_dict(best_state)
    return model

# %% [markdown]
# ## TCN Classification Training

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from val_test import val_test

n_folds = 30
models_clf = {'TCN': []}
name = list(models_clf.keys())[0]

all_results_validation_clf = {name: {'targets': [], 'preds': []}}
all_results_test_clf = {name: {'targets': [], 'preds': [], 'subjects': []}}

for k in tqdm(range(n_folds)):

    model = TCN(N_gaits=2, output_dim=3).to(device)  # 3-class logits

    validation_pids, test_pids = val_test(participant_ids, k)
    print(f"Fold {k+1} | Validation Subs: {validation_pids} | Test Subs: {test_pids}")

    train_loader, val_loader, test_loader = cv_data_create(validation_pids, test_pids, save_dir, batch_size=bsize)
    trained_model = train_model_clf(model, train_loader, experiment_seed=k, num_epochs=1000, N_gaits=2,
                                    val_loader=val_loader, patience=150, num_classes=3)

    val_t, val_p = evaluate_model_clf(trained_model, val_loader, n_select_gaits=2, num_classes=3)
    test_t, test_p = evaluate_model_clf(trained_model, test_loader, n_select_gaits=2, num_classes=3)

    all_results_validation_clf[name]['targets'].extend(val_t)
    all_results_validation_clf[name]['preds'].extend(val_p)

    all_results_test_clf[name]['targets'].extend(test_t)
    all_results_test_clf[name]['preds'].extend(test_p)
    all_results_test_clf[name]['subjects'].extend(test_pids)

    acc_val = accuracy_score(val_t, val_p)
    f1m_val = f1_score(val_t, val_p, average='macro')
    print(f"Fold {k + 1:02d} | {name} | Validation: Acc={acc_val:.3f}, F1-macro={f1m_val:.3f}\n")

# Overall pooled (OOF) metrics across all folds
val_t_all = np.array(all_results_validation_clf[name]['targets'])
val_p_all = np.array(all_results_validation_clf[name]['preds'])
test_t_all = np.array(all_results_test_clf[name]['targets'])
test_p_all = np.array(all_results_test_clf[name]['preds'])

def classification_metrics(t, p):
    return {
        'Accuracy': accuracy_score(t, p),
        'F1 (weighted)': f1_score(t, p, average='weighted'),
        'F1 (macro)': f1_score(t, p, average='macro'),
        'Precision (weighted)': precision_score(t, p, average='weighted', zero_division=0),
        'Precision (macro)': precision_score(t, p, average='macro', zero_division=0),
        'Recall (weighted)': recall_score(t, p, average='weighted', zero_division=0),
        'Recall (macro)': recall_score(t, p, average='macro', zero_division=0),
    }

results_val = classification_metrics(val_t_all, val_p_all)
results_test = classification_metrics(test_t_all, test_p_all)

print("\n=== Validation Performance (across all folds) ===")
print(pd.DataFrame({name: results_val}).T)

print("\n=== Test Performance (across all folds) ===")
results_test_df = pd.DataFrame({name: results_test}).T
results_test_df
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Fold 1 | Validation Subs: ['1', '2', '3', '4', '5'] | Test Subs: ['6', '7', '8', '10', '11']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0001 | Val CE loss: 4.4859 | Val Acc: 0.6000
# Early stopping at epoch 151 (no improvement for 150 epochs)
# Fold 01 | TCN | Validation: Acc=0.000, F1-macro=0.000
#
# Fold 2 | Validation Subs: ['13', '14', '15', '17', '18'] | Test Subs: ['19', '20', '21', '22', '23']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0008 | Val CE loss: 5.4416 | Val Acc: 0.6000
# Early stopping at epoch 153 (no improvement for 150 epochs)
# Fold 02 | TCN | Validation: Acc=0.600, F1-macro=0.375
#
# Fold 3 | Validation Subs: ['24', '25', '26', '27', '28'] | Test Subs: ['29', '30', '31', '32', '33']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0004 | Val CE loss: 3.1203 | Val Acc: 0.6000
# Early stopping at epoch 165 (no improvement for 150 epochs)
# Fold 03 | TCN | Validation: Acc=0.600, F1-macro=0.583
#
# Fold 4 | Validation Subs: ['34', '35', '36', '37', '38'] | Test Subs: ['40', '41', '42', '43', '45']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0129 | Val CE loss: 0.9289 | Val Acc: 0.8000
# Early stopping at epoch 162 (no improvement for 150 epochs)
# Fold 04 | TCN | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 5 | Validation Subs: ['46', '47', '48', '49', '51'] | Test Subs: ['52', '53', '54', '55', '56']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0268 | Val CE loss: 0.2138 | Val Acc: 0.8000
# [Epoch 200/1000] Train CE loss: 0.0002 | Val CE loss: 0.2733 | Val Acc: 1.0000
# Early stopping at epoch 298 (no improvement for 150 epochs)
# Fold 05 | TCN | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 6 | Validation Subs: ['57', '58', '59', '60', '61'] | Test Subs: ['62', '63', '64', '65', '66']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0046 | Val CE loss: 0.0008 | Val Acc: 1.0000
# [Epoch 200/1000] Train CE loss: 0.0001 | Val CE loss: 0.0017 | Val Acc: 1.0000
# [Epoch 300/1000] Train CE loss: 0.0021 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 400/1000] Train CE loss: 0.0000 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 500/1000] Train CE loss: 0.0001 | Val CE loss: 0.0026 | Val Acc: 1.0000
# Early stopping at epoch 588 (no improvement for 150 epochs)
# Fold 06 | TCN | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 7 | Validation Subs: ['67', '68', '69', '70', '71'] | Test Subs: ['72', '73', '74', '75', '76']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0106 | Val CE loss: 0.0001 | Val Acc: 1.0000
# [Epoch 200/1000] Train CE loss: 0.0006 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 300/1000] Train CE loss: 0.0000 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 400/1000] Train CE loss: 0.0001 | Val CE loss: 0.0000 | Val Acc: 1.0000
# Early stopping at epoch 429 (no improvement for 150 epochs)
# Fold 07 | TCN | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 8 | Validation Subs: ['77', '78', '79', '80', '81'] | Test Subs: ['82', '83', '84', '85', '86']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0434 | Val CE loss: 0.0304 | Val Acc: 1.0000
# [Epoch 200/1000] Train CE loss: 0.0001 | Val CE loss: 0.0001 | Val Acc: 1.0000
# Early stopping at epoch 240 (no improvement for 150 epochs)
# Fold 08 | TCN | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 9 | Validation Subs: ['87', '88', '89', '90', '92'] | Test Subs: ['94', '95', '97', '98', '99']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0003 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 200/1000] Train CE loss: 0.0001 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 300/1000] Train CE loss: 0.0000 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 400/1000] Train CE loss: 0.0000 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 500/1000] Train CE loss: 0.0000 | Val CE loss: 0.0000 | Val Acc: 1.0000
# Early stopping at epoch 520 (no improvement for 150 epochs)
# Fold 09 | TCN | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 10 | Validation Subs: ['100', '102', '103', '105', '106'] | Test Subs: ['107', '109', '111', '112', '113']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0018 | Val CE loss: 0.4151 | Val Acc: 1.0000
# [Epoch 200/1000] Train CE loss: 0.0001 | Val CE loss: 0.4228 | Val Acc: 1.0000
# Early stopping at epoch 265 (no improvement for 150 epochs)
# Fold 10 | TCN | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 11 | Validation Subs: ['115', '117', '118', '119', '120'] | Test Subs: ['121', '122', '123', '125', '126']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0003 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 200/1000] Train CE loss: 0.0031 | Val CE loss: 0.0001 | Val Acc: 1.0000
# [Epoch 300/1000] Train CE loss: 0.0000 | Val CE loss: 0.0000 | Val Acc: 1.0000
# Early stopping at epoch 377 (no improvement for 150 epochs)
# Fold 11 | TCN | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 12 | Validation Subs: ['127', '128', '129', '131', '133'] | Test Subs: ['134', '135', '136', '137', '138']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0001 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 200/1000] Train CE loss: 0.0292 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 300/1000] Train CE loss: 0.0001 | Val CE loss: 0.0000 | Val Acc: 1.0000
# Early stopping at epoch 350 (no improvement for 150 epochs)
# Fold 12 | TCN | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 13 | Validation Subs: ['139', '140', '141', '142', '143'] | Test Subs: ['144', '145', '148', '149', '150']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0002 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 200/1000] Train CE loss: 0.0003 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 300/1000] Train CE loss: 0.0000 | Val CE loss: 0.0000 | Val Acc: 1.0000
# Early stopping at epoch 353 (no improvement for 150 epochs)
# Fold 13 | TCN | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 14 | Validation Subs: ['151', '153', '154', '155', '156'] | Test Subs: ['157', '158', '159', '160', '162']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0005 | Val CE loss: 0.0445 | Val Acc: 1.0000
# [Epoch 200/1000] Train CE loss: 0.0002 | Val CE loss: 0.0327 | Val Acc: 1.0000
# [Epoch 300/1000] Train CE loss: 0.0001 | Val CE loss: 0.0196 | Val Acc: 1.0000
# Early stopping at epoch 389 (no improvement for 150 epochs)
# Fold 14 | TCN | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 15 | Validation Subs: ['164', '165', '167', '168', '171'] | Test Subs: ['173', '174', '175', '179', '180', '183', '184', '185', '187', '188']
# Created 700 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0003 | Val CE loss: 0.0001 | Val Acc: 1.0000
# [Epoch 200/1000] Train CE loss: 0.0000 | Val CE loss: 0.0001 | Val Acc: 1.0000
# [Epoch 300/1000] Train CE loss: 0.0000 | Val CE loss: 0.0000 | Val Acc: 1.0000
# Early stopping at epoch 364 (no improvement for 150 epochs)
# Fold 15 | TCN | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 16 | Validation Subs: ['6', '7', '8', '10', '11'] | Test Subs: ['1', '2', '3', '4', '5']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0001 | Val CE loss: 4.1679 | Val Acc: 0.4000
# Early stopping at epoch 152 (no improvement for 150 epochs)
# Fold 16 | TCN | Validation: Acc=0.800, F1-macro=0.444
#
# Fold 17 | Validation Subs: ['19', '20', '21', '22', '23'] | Test Subs: ['13', '14', '15', '17', '18']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0004 | Val CE loss: 3.5425 | Val Acc: 0.4000
# Early stopping at epoch 152 (no improvement for 150 epochs)
# Fold 17 | TCN | Validation: Acc=0.400, F1-macro=0.267
#
# Fold 18 | Validation Subs: ['29', '30', '31', '32', '33'] | Test Subs: ['24', '25', '26', '27', '28']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0002 | Val CE loss: 1.7802 | Val Acc: 0.4000
# Early stopping at epoch 166 (no improvement for 150 epochs)
# Fold 18 | TCN | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 19 | Validation Subs: ['40', '41', '42', '43', '45'] | Test Subs: ['34', '35', '36', '37', '38']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0005 | Val CE loss: 4.2426 | Val Acc: 0.6000
# Early stopping at epoch 151 (no improvement for 150 epochs)
# Fold 19 | TCN | Validation: Acc=0.800, F1-macro=0.444
#
# Fold 20 | Validation Subs: ['52', '53', '54', '55', '56'] | Test Subs: ['46', '47', '48', '49', '51']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0009 | Val CE loss: 0.0010 | Val Acc: 1.0000
# [Epoch 200/1000] Train CE loss: 0.0103 | Val CE loss: 0.0000 | Val Acc: 1.0000
# Early stopping at epoch 258 (no improvement for 150 epochs)
# Fold 20 | TCN | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 21 | Validation Subs: ['62', '63', '64', '65', '66'] | Test Subs: ['57', '58', '59', '60', '61']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0002 | Val CE loss: 0.4351 | Val Acc: 0.8000
# [Epoch 200/1000] Train CE loss: 0.0031 | Val CE loss: 0.1104 | Val Acc: 1.0000
# Early stopping at epoch 207 (no improvement for 150 epochs)
# Fold 21 | TCN | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 22 | Validation Subs: ['72', '73', '74', '75', '76'] | Test Subs: ['67', '68', '69', '70', '71']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0271 | Val CE loss: 0.2741 | Val Acc: 0.8000
# Early stopping at epoch 178 (no improvement for 150 epochs)
# Fold 22 | TCN | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 23 | Validation Subs: ['82', '83', '84', '85', '86'] | Test Subs: ['77', '78', '79', '80', '81']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0003 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 200/1000] Train CE loss: 0.0002 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 300/1000] Train CE loss: 0.0001 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 400/1000] Train CE loss: 0.0000 | Val CE loss: 0.0000 | Val Acc: 1.0000
# Early stopping at epoch 493 (no improvement for 150 epochs)
# Fold 23 | TCN | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 24 | Validation Subs: ['94', '95', '97', '98', '99'] | Test Subs: ['87', '88', '89', '90', '92']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0018 | Val CE loss: 0.0000 | Val Acc: 1.0000
# Early stopping at epoch 194 (no improvement for 150 epochs)
# Fold 24 | TCN | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 25 | Validation Subs: ['107', '109', '111', '112', '113'] | Test Subs: ['100', '102', '103', '105', '106']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0002 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 200/1000] Train CE loss: 0.0011 | Val CE loss: 0.0000 | Val Acc: 1.0000
# Early stopping at epoch 261 (no improvement for 150 epochs)
# Fold 25 | TCN | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 26 | Validation Subs: ['121', '122', '123', '125', '126'] | Test Subs: ['115', '117', '118', '119', '120']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0183 | Val CE loss: 0.0000 | Val Acc: 1.0000
# Early stopping at epoch 187 (no improvement for 150 epochs)
# Fold 26 | TCN | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 27 | Validation Subs: ['134', '135', '136', '137', '138'] | Test Subs: ['127', '128', '129', '131', '133']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0016 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 200/1000] Train CE loss: 0.0001 | Val CE loss: 0.0001 | Val Acc: 1.0000
# Early stopping at epoch 277 (no improvement for 150 epochs)
# Fold 27 | TCN | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 28 | Validation Subs: ['144', '145', '148', '149', '150'] | Test Subs: ['139', '140', '141', '142', '143']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0003 | Val CE loss: 0.0000 | Val Acc: 1.0000
# [Epoch 200/1000] Train CE loss: 0.0001 | Val CE loss: 0.0000 | Val Acc: 1.0000
# Early stopping at epoch 278 (no improvement for 150 epochs)
# Fold 28 | TCN | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 29 | Validation Subs: ['157', '158', '159', '160', '162'] | Test Subs: ['151', '153', '154', '155', '156']
# Created 725 gait windows
# Created 25 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0003 | Val CE loss: 0.8363 | Val Acc: 0.8000
# [Epoch 200/1000] Train CE loss: 0.0003 | Val CE loss: 0.0588 | Val Acc: 1.0000
# [Epoch 300/1000] Train CE loss: 0.0001 | Val CE loss: 0.1137 | Val Acc: 1.0000
# Early stopping at epoch 324 (no improvement for 150 epochs)
# Fold 29 | TCN | Validation: Acc=1.000, F1-macro=1.000
#
# Fold 30 | Validation Subs: ['173', '174', '175', '179', '180', '183', '184', '185', '187', '188'] | Test Subs: ['164', '165', '167', '168', '171']
# Created 700 gait windows
# Created 50 gait windows
# Starting training...
# [Epoch 100/1000] Train CE loss: 0.0231 | Val CE loss: 0.3110 | Val Acc: 1.0000
# [Epoch 200/1000] Train CE loss: 0.0001 | Val CE loss: 0.4473 | Val Acc: 0.9000
# Early stopping at epoch 255 (no improvement for 150 epochs)
# Fold 30 | TCN | Validation: Acc=1.000, F1-macro=1.000
#
#
# === Validation Performance (across all folds) ===
#      Accuracy  F1 (weighted)  F1 (macro)  Precision (weighted)  \
# TCN  0.909677       0.898046    0.763035              0.905003
#
#      Precision (macro)  Recall (weighted)  Recall (macro)
# TCN           0.860154           0.909677        0.730159
#
# === Test Performance (across all folds) ===
#      Accuracy  F1 (weighted)  F1 (macro)  Precision (weighted)  \
# TCN  0.858065       0.839166    0.637356              0.833443
#
#      Precision (macro)  Recall (weighted)  Recall (macro)
# TCN           0.698642           0.858065        0.615873

# %%
from ci_class import subject_bootstrap_ci_class

ci_results = {}

name = "TCN"

ci_results[name] = subject_bootstrap_ci_class(
    all_results_test_clf[name]['targets'],
    all_results_test_clf[name]['preds'],
    all_results_test_clf[name]['subjects'])

pd.DataFrame(ci_results['TCN'])
# Out:
#             Accuracy   F1 (weighted)      F1 (macro) Precision (weighted)  \
# mean        0.858065        0.839166        0.637356             0.833443
# ci    [0.814, 0.902]  [0.788, 0.891]  [0.533, 0.719]       [0.776, 0.896]
#
#      Precision (macro) Recall (weighted)  Recall (macro)
# mean          0.698642          0.858065        0.615873
# ci      [0.529, 0.865]    [0.814, 0.902]  [0.537, 0.689]
